# %% [markdown]
# # Python for Data Science Practice Session 1 : Mathematics and Statistics

# %% [markdown]
# ## A walk through history

# %% [markdown]
# In this session, we are going to analyse a dataset containing Mathematicians that have helped shape what Maths - as well as many other fields - have become today. This is a great chance for you to learn more about previous Mathematicians starting from where they're from, the fields they were interested in, the occupations they had and many other stuff that you can explore.
#
# We start by importing the libraries that we are going to need for this project:

# %%
# Import pandas  
import pandas as pd

# %%
# This is a library that is used in one of the pre-written codes
import itertools

# %%
# Upload the file named mathematicians.csv into a dataframe
df = pd.read_csv('mathematicians.csv')

# %%
# View the dataframe
df
# Out:
#               mathematicians  \
# 0     Roger Joseph Boscovich
# 1              Emma Previato
# 2              Feodor Deahna
# 3              Denis Henrion
# 4             Henri Delannoy
# ...                      ...
# 8591  Hugh Hamilton (bishop)
# 8592            Boáz Klartag
# 8593         Alain M. Robert
# 8594      Paul C. Rosenbloom
# 8595         Edward O. Thorp
#
#                                              occupation  \
# 0     ['physicist', 'astronomer', 'mathematician', '...
# 1                                     ['mathematician']
# 2                                     ['mathematician']
# 3                        ['publisher', 'mathematician']
# 4     ['mathematician', 'historian', 'military perso...
# ...                                                 ...
# 8591                                         ['priest']
# 8592            ['mathematician', 'university teacher']
# 8593                                  ['mathematician']
# 8594                                  ['mathematician']
# 8595  ['mathematician', 'writer', 'university teacher']
#
#                      country of citizenship                 place of birth  \
# 0                    ['Republic of Ragusa']  Dubrovnik, Republic of Ragusa
# 1     ['United States of America', 'Italy']                 Badia Polesine
# 2                                       NaN                            NaN
# 3                                ['France']                            NaN
# 4                                ['France']            Bourbonne-les-Bains
# ...                                     ...                            ...
# 8591                                    NaN                  County Dublin
# 8592                             ['Israel']                            NaN
# 8593                        ['Switzerland']                            NaN
# 8594           ['United States of America']                     Portsmouth
# 8595           ['United States of America']                        Chicago
#
#          date of death                                    educated at  \
# 0     13 February 1787            ['Pontifical Gregorian University']
# 1                  NaN  ['Harvard University', 'University of Padua']
# 2                 1844                                            NaN
# 3                 1640                                            NaN
# 4      5 February 1915                        ['École Polytechnique']
# ...                ...                                            ...
# 8591   1 December 1805                     ['Trinity College Dublin']
# 8592               NaN                        ['Tel Aviv University']
# 8593               NaN                                            NaN
# 8594          May 2005                                            NaN
# 8595               NaN      ['University of California, Los Angeles']
#
#                                                employer  \
# 0                   ['Pontifical Gregorian University']
# 1          ['Boston University', 'University of Padua']
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8591                                                NaN
# 8592                                                NaN
# 8593                                                NaN
# 8594                                                NaN
# 8595  ['New Mexico State University', 'University of...
#
#                     place of death  \
# 0     ['Milan', 'Habsburg Empire']
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                       ['Guéret']
# ...                            ...
# 8591                  ['Kilkenny']
# 8592                           NaN
# 8593                           NaN
# 8594                           NaN
# 8595                           NaN
#
#                                               member of  \
# 0     ['Royal Society', 'Russian Academy of Sciences...
# 1                     ['American Mathematical Society']
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8591                                  ['Royal Society']
# 8592                                                NaN
# 8593                                                NaN
# 8594                                                NaN
# 8595                                                NaN
#
#                                              employer.1  ... instance of  \
# 0                   ['Pontifical Gregorian University']  ...   ['human']
# 1          ['Boston University', 'University of Padua']  ...   ['human']
# 2                                                   NaN  ...   ['human']
# 3                                                   NaN  ...   ['human']
# 4                                                   NaN  ...   ['human']
# ...                                                 ...  ...         ...
# 8591                                                NaN  ...   ['human']
# 8592                                                NaN  ...   ['human']
# 8593                                                NaN  ...   ['human']
# 8594                                                NaN  ...   ['human']
# 8595  ['New Mexico State University', 'University of...  ...   ['human']
#
#      sex or gender approx. date of birth day of birth month of birth  \
# 0         ['male']                 False         18.0            May
# 1       ['female']                 False          NaN            NaN
# 2         ['male']                 False          NaN            NaN
# 3         ['male']                  True          NaN            NaN
# 4         ['male']                 False         28.0      September
# ...            ...                   ...          ...            ...
# 8591      ['male']                 False         26.0          March
# 8592      ['male']                 False         25.0          April
# 8593      ['male']                 False         15.0        October
# 8594      ['male']                 False         31.0          March
# 8595      ['male']                 False         14.0         August
#
#      year of birth approx. date of death day of death month of death  \
# 0             1711                 False         13.0       February
# 1             1952                 False          NaN            NaN
# 2             1815                 False          NaN            NaN
# 3             1500                 False          NaN            NaN
# 4             1833                 False          5.0       February
# ...            ...                   ...          ...            ...
# 8591          1729                 False          1.0       December
# 8592          1978                 False          NaN            NaN
# 8593          1941                 False          NaN            NaN
# 8594          1920                 False          NaN            May
# 8595          1932                 False          NaN            NaN
#
#      year of death
# 0             1787
# 1              NaN
# 2             1844
# 3             1640
# 4             1915
# ...            ...
# 8591          1805
# 8592           NaN
# 8593           NaN
# 8594          2005
# 8595           NaN
#
# [8596 rows x 29 columns]

# %% [markdown]
# You might be wondering what NaN stands for. Well, NaN is an abbreviation for "Not a Number", and it is a member of the numeric data type but it is undefined or unrepresentable on the computer. Take 0/0 as an example, which is undefined. NaNs are treated as missing values by Python.
#
# This dataset is a great example on how real life datasets might look like, where datasets are not perfect and you will have to find a way to deal with those missing values.
#
# Anyways, let's proceed for now with getting a taste of what the dataset looks like and we'll get back to dealing with missing values in a bit.

# %%
# Output the dimensions of the dataframe
df.shape
# Out:
# (8596, 29)

# %%
# Output the data of 10 random mathematicians
df.sample(10)
# Out:
#            mathematicians                                         occupation  \
# 4945   Richard M. Goodwin                     ['mathematician', 'economist']
# 1641  Anthony Bartholomay                                               ['']
# 1435         Arthur Burks                                  ['mathematician']
# 814       Stan van Hoesel                                  ['mathematician']
# 4478           Yuri Manin            ['mathematician', 'university teacher']
# 4545       Harold W. Kuhn  ['mathematician', 'writer', 'university teache...
# 6659     Michael Sadowsky                                  ['mathematician']
# 6144      André Haefliger            ['mathematician', 'university teacher']
# 5277      C. P. Ramanujam                                  ['mathematician']
# 7460         S. L. Hakimi                                  ['mathematician']
#
#             country of citizenship  \
# 4945  ['United States of America']
# 1641                           NaN
# 1435  ['United States of America']
# 814                            NaN
# 4478   ['Soviet Union', 'Germany']
# 4545  ['United States of America']
# 6659                           NaN
# 6144               ['Switzerland']
# 5277                     ['India']
# 7460  ['United States of America']
#
#                                          place of birth     date of death  \
# 4945                                            Indiana    13 August 1996
# 1641                                                NaN     21 March 1975
# 1435                                             Duluth       14 May 2008
# 814                                                 NaN               NaN
# 4478  Simferopol, Russian Soviet Federative Socialis...               NaN
# 4545                                       Santa Monica       2 July 2014
# 6659                                                NaN  31 December 1967
# 6144                                               Nyon               NaN
# 5277                                            Chennai   27 October 1974
# 7460                                                NaN              2005
#
#                                             educated at  \
# 4945                             ['Harvard University']
# 1641                                                NaN
# 1435    ['University of Michigan', 'DePauw University']
# 814                                                 NaN
# 4478                        ['Moscow State University']
# 4545                                                NaN
# 6659                                                NaN
# 6144                       ['University of Strasbourg']
# 5277                           ['University of Madras']
# 7460  ['University of Illinois system', 'University ...
#
#                                  employer     place of death  \
# 4945               ['Harvard University']          ['Siena']
# 1641                                  NaN                NaN
# 1435           ['University of Michigan']      ['Ann Arbor']
# 814             ['Maastricht University']                NaN
# 4478  ['Northwestern University', '2002']                NaN
# 4545             ['Princeton University']  ['New York City']
# 6659                                  NaN                NaN
# 6144                                  NaN                NaN
# 5277                                  NaN      ['Bangalore']
# 7460          ['Northwestern University']                NaN
#
#                                               member of  \
# 4945                                                NaN
# 1641                                                NaN
# 1435                                                NaN
# 814                                                 NaN
# 4478  ['German Academy of Sciences Leopoldina', 'Fre...
# 4545          ['American Academy of Arts and Sciences']
# 6659                                                NaN
# 6144                                                NaN
# 5277                                                NaN
# 7460                                                NaN
#
#                                employer.1  ... instance of sex or gender  \
# 4945               ['Harvard University']  ...   ['human']      ['male']
# 1641                                  NaN  ...   ['human']      ['male']
# 1435           ['University of Michigan']  ...      ['Q5']      ['male']
# 814             ['Maastricht University']  ...   ['human']      ['male']
# 4478  ['Northwestern University', '2002']  ...   ['human']      ['male']
# 4545             ['Princeton University']  ...   ['human']      ['male']
# 6659                                  NaN  ...   ['human']      ['male']
# 6144                                  NaN  ...   ['human']      ['male']
# 5277                                  NaN  ...   ['human']      ['male']
# 7460          ['Northwestern University']  ...   ['human']      ['male']
#
#      approx. date of birth day of birth month of birth year of birth  \
# 4945                 False         24.0       February          1913
# 1641                 False         11.0         August          1919
# 1435                 False         13.0        October          1915
# 814                  False          NaN            NaN          1961
# 4478                 False         16.0       February          1937
# 4545                 False         29.0           July          1925
# 6659                 False          NaN            NaN          1902
# 6144                 False         22.0            May          1929
# 5277                 False         22.0       December          1887
# 7460                 False          NaN            NaN           NaN
#
#      approx. date of death day of death month of death year of death
# 4945                 False         13.0         August          1996
# 1641                 False         21.0          March          1975
# 1435                 False         14.0            May          2008
# 814                  False          NaN            NaN           NaN
# 4478                 False          NaN            NaN           NaN
# 4545                 False          2.0           July          2014
# 6659                 False         31.0       December          1967
# 6144                 False          NaN            NaN           NaN
# 5277                 False         27.0        October          1974
# 7460                 False          NaN            NaN          2005
#
# [10 rows x 29 columns]

# %% [markdown]
# Not all the column headings are visible in the previous output due to the large amount of columns.
#
# Let us output the column headings:

# %%
# View the column headings
df.columns.values.tolist()
# Out:
# ['mathematicians',
#  'occupation',
#  'country of citizenship',
#  'place of birth',
#  'date of death',
#  'educated at',
#  'employer',
#  'place of death',
#  'member of',
#  'employer.1',
#  'doctoral advisor',
#  'languages spoken, written or signed',
#  'academic degree',
#  'doctoral student',
#  'manner of death',
#  'position held',
#  'field of work',
#  'award received',
#  'Erdős number',
#  'instance of',
#  'sex or gender',
#  'approx. date of birth',
#  'day of birth',
#  'month of birth',
#  'year of birth',
#  'approx. date of death',
#  'day of death',
#  'month of death',
#  'year of death']

# %%
# Drop the following columns: 'Erdős number' , 'instance of', 'approx. date of birth' and 'approx. date of death'
df.drop(['Erdős number', 'instance of', 'approx. date of birth', 'approx. date of death'], axis=1)
# Out:
#               mathematicians  \
# 0     Roger Joseph Boscovich
# 1              Emma Previato
# 2              Feodor Deahna
# 3              Denis Henrion
# 4             Henri Delannoy
# ...                      ...
# 8591  Hugh Hamilton (bishop)
# 8592            Boáz Klartag
# 8593         Alain M. Robert
# 8594      Paul C. Rosenbloom
# 8595         Edward O. Thorp
#
#                                              occupation  \
# 0     ['physicist', 'astronomer', 'mathematician', '...
# 1                                     ['mathematician']
# 2                                     ['mathematician']
# 3                        ['publisher', 'mathematician']
# 4     ['mathematician', 'historian', 'military perso...
# ...                                                 ...
# 8591                                         ['priest']
# 8592            ['mathematician', 'university teacher']
# 8593                                  ['mathematician']
# 8594                                  ['mathematician']
# 8595  ['mathematician', 'writer', 'university teacher']
#
#                      country of citizenship                 place of birth  \
# 0                    ['Republic of Ragusa']  Dubrovnik, Republic of Ragusa
# 1     ['United States of America', 'Italy']                 Badia Polesine
# 2                                       NaN                            NaN
# 3                                ['France']                            NaN
# 4                                ['France']            Bourbonne-les-Bains
# ...                                     ...                            ...
# 8591                                    NaN                  County Dublin
# 8592                             ['Israel']                            NaN
# 8593                        ['Switzerland']                            NaN
# 8594           ['United States of America']                     Portsmouth
# 8595           ['United States of America']                        Chicago
#
#          date of death                                    educated at  \
# 0     13 February 1787            ['Pontifical Gregorian University']
# 1                  NaN  ['Harvard University', 'University of Padua']
# 2                 1844                                            NaN
# 3                 1640                                            NaN
# 4      5 February 1915                        ['École Polytechnique']
# ...                ...                                            ...
# 8591   1 December 1805                     ['Trinity College Dublin']
# 8592               NaN                        ['Tel Aviv University']
# 8593               NaN                                            NaN
# 8594          May 2005                                            NaN
# 8595               NaN      ['University of California, Los Angeles']
#
#                                                employer  \
# 0                   ['Pontifical Gregorian University']
# 1          ['Boston University', 'University of Padua']
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8591                                                NaN
# 8592                                                NaN
# 8593                                                NaN
# 8594                                                NaN
# 8595  ['New Mexico State University', 'University of...
#
#                     place of death  \
# 0     ['Milan', 'Habsburg Empire']
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                       ['Guéret']
# ...                            ...
# 8591                  ['Kilkenny']
# 8592                           NaN
# 8593                           NaN
# 8594                           NaN
# 8595                           NaN
#
#                                               member of  \
# 0     ['Royal Society', 'Russian Academy of Sciences...
# 1                     ['American Mathematical Society']
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8591                                  ['Royal Society']
# 8592                                                NaN
# 8593                                                NaN
# 8594                                                NaN
# 8595                                                NaN
#
#                                              employer.1  ... position held  \
# 0                   ['Pontifical Gregorian University']  ...           NaN
# 1          ['Boston University', 'University of Padua']  ...           NaN
# 2                                                   NaN  ...           NaN
# 3                                                   NaN  ...           NaN
# 4                                                   NaN  ...           NaN
# ...                                                 ...  ...           ...
# 8591                                                NaN  ...           NaN
# 8592                                                NaN  ...           NaN
# 8593                                                NaN  ...           NaN
# 8594                                                NaN  ...           NaN
# 8595  ['New Mexico State University', 'University of...  ...           NaN
#
#                   field of work  \
# 0                           NaN
# 1                           NaN
# 2     ['differential geometry']
# 3                           NaN
# 4                           NaN
# ...                         ...
# 8591                        NaN
# 8592                        NaN
# 8593                        NaN
# 8594                        NaN
# 8595     ['probability theory']
#
#                                          award received sex or gender  \
# 0                       ['Fellow of the Royal Society']      ['male']
# 1                                                   NaN    ['female']
# 2                                                   NaN      ['male']
# 3                                                   NaN      ['male']
# 4                                                   NaN      ['male']
# ...                                                 ...           ...
# 8591                    ['Fellow of the Royal Society']      ['male']
# 8592                            ['Salem Prize', '2008']      ['male']
# 8593                                                NaN      ['male']
# 8594  ['John Simon Guggenheim Memorial Foundation Fe...      ['male']
# 8595                                                NaN      ['male']
#
#      day of birth month of birth year of birth day of death month of death  \
# 0            18.0            May          1711         13.0       February
# 1             NaN            NaN          1952          NaN            NaN
# 2             NaN            NaN          1815          NaN            NaN
# 3             NaN            NaN          1500          NaN            NaN
# 4            28.0      September          1833          5.0       February
# ...           ...            ...           ...          ...            ...
# 8591         26.0          March          1729          1.0       December
# 8592         25.0          April          1978          NaN            NaN
# 8593         15.0        October          1941          NaN            NaN
# 8594         31.0          March          1920          NaN            May
# 8595         14.0         August          1932          NaN            NaN
#
#       year of death
# 0              1787
# 1               NaN
# 2              1844
# 3              1640
# 4              1915
# ...             ...
# 8591           1805
# 8592            NaN
# 8593            NaN
# 8594           2005
# 8595            NaN
#
# [8596 rows x 25 columns]

# %%
# Output the number of columns
#len(df.columns.values.tolist())
df.columns.size
# Out:
# 29

# %% [markdown]
# - - - -

# %% [markdown]
# ## Let's talk about missing values

# %% [markdown]
# So we have a total of 25 columns. Let's check how many missing values each column has individually.

# %%
# Output the total number of missing values per column
df.isna().sum()
# Out:
# mathematicians                            0
# occupation                                0
# country of citizenship                 1721
# place of birth                         3026
# date of death                          3702
# educated at                            3869
# employer                               5086
# place of death                         5436
# member of                              5505
# employer.1                             5086
# doctoral advisor                       6145
# languages spoken, written or signed    6269
# academic degree                        8097
# doctoral student                       8292
# manner of death                        8373
# position held                          8377
# field of work                          6163
# award received                         6249
# Erdős number                           7122
# instance of                               0
# sex or gender                            28
# approx. date of birth                     0
# day of birth                           2826
# month of birth                         2791
# year of birth                           971
# approx. date of death                     0
# day of death                           4610
# month of death                         4570
# year of death                          3703
# dtype: int64

# %% [markdown]
#  - - - - - -
# As you can see, most of the columns have a large amount of missing values which is an issue. After all, the analysis you make is as good as the data that you have. What this means in our case is that due to the large amount of missing values per column, the analysis that we do might not be of the best quality.
#
# One of the problems that we could face is having a pattern in the missing values. An example would be that older Mathematicians might have less information associated with them compared to the most recent ones (I will leave this for you to explore on your own to check and see if this is the case here if you are interested). As a result, this might introduce bias in your analysis, where the outputs you get from your analysis are not the best representatives for the older mathematicians because most of the data used in your analysis will be associated with recent Mathematicians, hence biased towards recent Mathematicians.
#
# What we would like to have is a missing value free dataset with a broad variety of Mathematicians.
# - - - - - - - - - - - - - - -
# In the next task, I would like for you to pick a random mathematician and fill in the missing values by doing a quick research.

# %%
# The following steps that you should follow are: 

# 1) Pick a random mathematician 
# 2) Do a quick research on them
# 3) Fill in their missing data manually in the dataframe

# %% [markdown]
# In a real world case scenario, we will not fill in each missing value manually as it is extremely in-efficient.
#
# A solution to this is called Web Scraping, which is the technique used to automatically scrape data from the internet using Python libraries, with the most popular one being called Beautiful Soup. It is extremely powerful in the sense that it is able to collect large sums of data by the click of a button, saving the massive amount of time that is needed to collect the data manually.
#
# Even though Web Scraping is beyond the scope of this course, I would recommend reading more about it on your own. You can find more about Web Scraping and Beautiful Soup here: https://realpython.com/beautiful-soup-web-scraper-python/
#
# Keep in mind that there are different types of missing values (eg: numeric missing values) and different ways of dealing with them. We will return back to this topic in the upcoming sessions.
# - - - - -

# %% [markdown]
# ----

# %% [markdown]
# ## List of occupations

# %%
# View the occupation column
df[['occupation']]
# Out:
#                                              occupation
# 0     ['physicist', 'astronomer', 'mathematician', '...
# 1                                     ['mathematician']
# 2                                     ['mathematician']
# 3                        ['publisher', 'mathematician']
# 4     ['mathematician', 'historian', 'military perso...
# ...                                                 ...
# 8591                                         ['priest']
# 8592            ['mathematician', 'university teacher']
# 8593                                  ['mathematician']
# 8594                                  ['mathematician']
# 8595  ['mathematician', 'writer', 'university teacher']
#
# [8596 rows x 1 columns]

# %% [markdown]
# Lots of the Mathematicians worked multiple occupations as you can see. Let us analyse the different occupations in the dataset.

# %%
# View the unique entries in the occupation column, then save it in a list called unique_occ
unique_occ = df.occupation.unique()

# %%
# View unique_occ
unique_occ
# Out:
# array(["['physicist', 'astronomer', 'mathematician', 'philosopher', 'diplomat', 'poet', 'theologian', 'priest', 'polymath', 'historian', 'scientist', 'writer', 'cleric', 'university teacher']",
#        "['mathematician']", "['publisher', 'mathematician']", ...,
#        "['politician', 'physicist', 'mathematician', 'nuclear scientist']",
#        "['mathematician', 'astronomer', 'philosopher', 'astrologer']",
#        "['mathematician', 'professeur des universités', 'researcher']"],
#       dtype=object)

# %% [markdown]
# the occupation "mathematician" is repeated in both ['mathematician'] and ['publisher', 'mathematician'] in unique_occ. This is because the entries are different, and so they are treated as unique results. This deems the <b>unique()</b> function useless in outputting a list of the unique occupations.
#
# In the following tasks, we will work towards outputting a list of the unique occupations.

# %%
# This code created a list called flat_list which takes each entry in df.occupation.unique(), splits each occupation  
# from the other occupations and puts it in its own entry
item_list = []
for item in unique_occ:
    item = item.split(",")
    item_list.append(item)
flat_list = itertools.chain(*item_list)
flat_list = list(flat_list)

# %%
# Print the first 30 entries of flat_list
flat_list[0:30]
# Out:
# ["['physicist'",
#  " 'astronomer'",
#  " 'mathematician'",
#  " 'philosopher'",
#  " 'diplomat'",
#  " 'poet'",
#  " 'theologian'",
#  " 'priest'",
#  " 'polymath'",
#  " 'historian'",
#  " 'scientist'",
#  " 'writer'",
#  " 'cleric'",
#  " 'university teacher']",
#  "['mathematician']",
#  "['publisher'",
#  " 'mathematician']",
#  "['mathematician'",
#  " 'historian'",
#  " 'military personnel']",
#  "['mathematician'",
#  " 'university teacher']",
#  "['']",
#  "['mathematician'",
#  " 'theoretical physicist'",
#  " 'inventor'",
#  " 'academic'",
#  " 'non-fiction writer'",
#  " 'physicist']",
#  "['civil engineer'"]

# %%
# Compare the length unique_occ with flat_list 
print("Length of unique_occ is", len(unique_occ), "while length of flat_list is", len(flat_list) )
# Out:
# Length of unique_occ is 1443 while length of flat_list is 5289

# %% [markdown]
# As you can see in the first 30 entries of flat_list, the format still has a few issues. For example, we have 'mathematician', ['mathematician'] and 'mathematician'] which all represent the same thing but are written in different ways. They are going to be treated by Python as distinct entries when trying to filter out the distinct values from the list.
#
# To solve this, we will loop over the entries in flat_list and use a function called <b>replace</b> that will help remove unwanted characters in order for all of the entries to have a unified format. Read more about how to use it here: https://www.w3schools.com/python/ref_string_replace.asp
#
# I would recommend solving this issue by removing each unwanted character individually, checking out how the output looks like afterwards, identifying another character that needs to be removed and then repeating the process until we end up with a unified format for all the entries. This helps in making the process much simpler.
#
# One thing to keep in mind is that Python is really sensitive to cases and spacings. So, 'Mathematician' isn't the same as 'mathematician', and   '[' is not the same as  ' [' .
#
#
# <b> HINT:</b> Writing ' ' in the second parameter of the function <b>replace</b> will remove the character instead of replacing it with another character.

# %%
# Loop through flat_list and use replace to remove unwanted characters, then save every new entry
# in the new list called flat_list2
flat_list2 = []
for s in flat_list:
    s = s.replace(']', '')
    s = s.replace('[', '')
    s = s.replace(" '", '')
    s = s.replace("'",'')
    flat_list2.append(s)

# %%
# Print out the first 30 entries of flat_list2
flat_list2[0:30]
# Out:
# ['physicist',
#  'astronomer',
#  'mathematician',
#  'philosopher',
#  'diplomat',
#  'poet',
#  'theologian',
#  'priest',
#  'polymath',
#  'historian',
#  'scientist',
#  'writer',
#  'cleric',
#  'university teacher',
#  'mathematician',
#  'publisher',
#  'mathematician',
#  'mathematician',
#  'historian',
#  'military personnel',
#  'mathematician',
#  'university teacher',
#  '',
#  'mathematician',
#  'theoretical physicist',
#  'inventor',
#  'academic',
#  'non-fiction writer',
#  'physicist',
#  'civil engineer']

# %% [markdown]
# Problem solved! Now use the function called <b>set</b> to retrieve the unique occupations from flat_list2. Read more about how to use it from here: https://www.geeksforgeeks.org/python-set-method/

# %%
# Retrieve the unique occupations from flat_list2
flat_list_unique = set(flat_list2)

# %%
# Print out the length of the list of unique occupations
len(flat_list_unique)
# Out:
# 414

# %%
# Print out the list of unique occupations
flat_list_unique
# Out:
# {'',
#  '"childrens writer"',
#  '"marja"',
#  '16112',
#  '1803',
#  '1804',
#  '1835',
#  '1841',
#  '1868',
#  '1874',
#  '1893',
#  '1931',
#  '1939',
#  '1981',
#  '2000',
#  '2002',
#  '2003',
#  '7 December 2016',
#  'American football player',
#  'Anglican priest',
#  'Australian rules footballer',
#  'Bible translator',
#  'Brazzers',
#  'Briggs',
#  'Catedrático de universidad',
#  'Catholic priest',
#  'Christian apologetics',
#  'Christian theology',
#  'Digambara monk',
#  'Director of Research at CNRS',
#  'Dutch Wikipedia',
#  'Encyclopédistes',
#  'English Wikipedia',
#  'Esperantist',
#  'French moralists',
#  'German Wikipedia',
#  'Hellenist',
#  'Hubrecht Institute',
#  'Huygens',
#  'Idist',
#  'India',
#  'Indologist',
#  'Ingen',
#  'Intelligence analysis',
#  'International School for Advanced Studies',
#  'Judaic scholar',
#  'Justice of the Peace',
#  'Latin',
#  'McGill University',
#  'Médico de familia',
#  'Napier',
#  'On the history of logarithms : Bürgi',
#  'Paris Diderot University',
#  'Persian Wikipedia',
#  'Posek',
#  'Q16267607',
#  'Q19163412',
#  'Q27686666',
#  'Q28078592',
#  'Q30134437',
#  'Q901',
#  'Russian Wikipedia',
#  'Sanskrit scholar',
#  'University of Turku',
#  'University of Waterloo',
#  'University of Zurich',
#  'Vlacq',
#  'Yachtmaster',
#  'academic',
#  'academician',
#  'accountant',
#  'activist',
#  'actor',
#  'actuary',
#  'administrator',
#  'aerospace engineer',
#  'agronomist',
#  'alchemist',
#  'algebraic geometry',
#  'analytic philosopher',
#  'anatomist',
#  'anthropologist',
#  'anti-vaccine activist',
#  'anti-war activist',
#  'arabist',
#  'archaeologist',
#  'architect',
#  'archivist',
#  'art collector',
#  'art historian',
#  'artificial intelligence researcher',
#  'artist',
#  'association football manager',
#  'association football player',
#  'association football referee',
#  'assyriologist',
#  'astrologer',
#  'astronaut',
#  'astronomer',
#  'astrophysicist',
#  'athletics competitor',
#  'author',
#  'autobiographer',
#  'aviator',
#  'badminton player',
#  'banker',
#  'basketball player',
#  'beekeeper',
#  'biochemist',
#  'biographer',
#  'bioinformatician',
#  'biologist',
#  'biophysicist',
#  'bishop',
#  'blogger',
#  'bodybuilding',
#  'botanist',
#  'bridge player',
#  'businessperson',
#  'calculus of variations',
#  'calligrapher',
#  'cardinal',
#  'cartographer',
#  'cellist',
#  'chairperson',
#  'chemist',
#  'chess composer',
#  'chess official',
#  'chess player',
#  'circus performer',
#  'civil engineer',
#  'civil servant',
#  'classical philologist',
#  'classical scholar',
#  'cleric',
#  'clockmaker',
#  'cognitive scientist',
#  'coin collecting',
#  'comedian',
#  'composer',
#  'computational biologist',
#  'computer scientist',
#  'consultant',
#  'contributing editor',
#  'correspondent',
#  'cosmographer',
#  'cosmologist',
#  'cricketer',
#  'criminologist',
#  'critic',
#  'cryptanalyst',
#  'cryptographer',
#  'cryptologist',
#  'curator',
#  'de Decker',
#  'deacon',
#  'demographer',
#  'designer',
#  'diarist',
#  'diplomat',
#  'director',
#  'disc jockey',
#  'dissident',
#  'docent',
#  'draughtsperson',
#  'ecologist',
#  'econometrician',
#  'economic historian',
#  'economist',
#  'editor',
#  'educator',
#  'egyptologist',
#  'engineer',
#  'engineer of roads and bridges',
#  'entomologist',
#  'entrepreneur',
#  'epidemiologist',
#  'epigrammatist',
#  'epistemologist',
#  'essayist',
#  'ethicist',
#  'explorer',
#  'faculty',
#  'faqih',
#  'farmer',
#  'fencer',
#  'film actor',
#  'film director',
#  'financier',
#  'full professor',
#  'game designer',
#  'game theory',
#  'gemcutter',
#  'genealogist',
#  'geneticist',
#  'geodesist',
#  'geographer',
#  'geologist',
#  'geomatics engineering',
#  'geophysicist',
#  'geopolitician',
#  'grammarian',
#  'hagiographer',
#  'head coach',
#  'head teacher',
#  'hellenist',
#  'high school teacher',
#  'historian',
#  'historian of cartography',
#  'historian of mathematics',
#  'historian of science',
#  'history of science',
#  'horticulturist',
#  'http://www.infoplease.com/biography/science-mathematicians.html',
#  'http://www.nndb.com/cemetery/815/000208191/',
#  'http://www.tandfonline.com/doi/full/10.1080/10926480903028094',
#  'http://www.worldatlas.com/webimage/countrys/europe/england/ukefamous3.htm',
#  'human computer',
#  'human rights activist',
#  'hydrologist',
#  'ichthyologist',
#  'informant',
#  'interlinguist',
#  'inventor',
#  'investor',
#  'jazz musician',
#  'journalist',
#  'judge',
#  'juggler',
#  'jurist',
#  'lacrosse player',
#  'lawyer',
#  'lecturer',
#  'lexicographer',
#  'librarian',
#  'librettist',
#  'linguist',
#  'literary',
#  'literary critic',
#  'literary historian',
#  'logician',
#  'lyricist',
#  'magistrate',
#  'malariologist',
#  'mathematical economics',
#  'mathematician',
#  'mathematics',
#  'mechanic',
#  'mechanical engineer',
#  'mechanician',
#  'media critic',
#  'metallurgist',
#  'metaphysician',
#  'meteorologist',
#  'microbiologist',
#  'military historian',
#  'military personnel',
#  'mineralogist',
#  'mining engineer',
#  'minister',
#  'missionary',
#  'model',
#  'monk',
#  'music educator',
#  'music historian',
#  'music theorist',
#  'musician',
#  'musicologist',
#  'mycologist',
#  'mystic',
#  'mythographer',
#  'natural philosophy',
#  'naturalist',
#  'navy officer',
#  'neurologist',
#  'neuroscientist',
#  'newspaper editor',
#  'noble',
#  'non-fiction writer',
#  'notary',
#  'novelist',
#  'nuclear scientist',
#  'numismatist',
#  'nun',
#  'occultist',
#  'oceanographer',
#  'officer',
#  'official',
#  'opinion journalist',
#  'orator',
#  'orientalist',
#  'ornithologist',
#  'pacifist',
#  'painter',
#  'paleontologist',
#  'papyrologist',
#  'paramedic',
#  'parson',
#  'partial differential equation',
#  'patent inventor',
#  'patron of the arts',
#  'peace activist',
#  'pharmacist',
#  'philanthropist',
#  'philatelist',
#  'philologist',
#  'philosopher',
#  'philosopher of language',
#  'philosopher of science',
#  'philosophy historian',
#  'photographer',
#  'physician',
#  'physicist',
#  'physiologist',
#  'pianist',
#  'playwright',
#  'poet',
#  'poet lawyer',
#  'poker player',
#  'political activist',
#  'political philosopher',
#  'political prisoner',
#  'political scientist',
#  'political writer',
#  'politician',
#  'polygraph',
#  'polymath',
#  'pragmatist',
#  'priest',
#  'printer',
#  'printmaker',
#  'probability theory',
#  'professeur des universités',
#  'professor',
#  'programmer',
#  'psephologist',
#  'psychiatrist',
#  'psychologist',
#  'psychology',
#  'public speaker',
#  'publisher',
#  'pupil',
#  'qadi',
#  'quantum physicist',
#  'rabbi',
#  'radio personality',
#  'radiologist',
#  'religious',
#  'research fellow',
#  'researcher',
#  'resistance fighter',
#  'revolutionary',
#  'roboticist',
#  'rower',
#  'rugby union player',
#  'sailor',
#  'salonnière',
#  'saxophonist',
#  'school teacher',
#  'science fiction writer',
#  'science writer',
#  'scientist',
#  'screenwriter',
#  'scribe',
#  'sculptor',
#  'seismologist',
#  'selenographer',
#  'singer',
#  'singer-songwriter',
#  'social critic',
#  'social philosopher',
#  'social scientist',
#  'sociologist',
#  'software engineer',
#  'songwriter',
#  'sophist',
#  'speleologist',
#  'sport cyclist',
#  'squash player',
#  'stage actor',
#  'stage magician',
#  'statesman',
#  'statistician',
#  'street artist',
#  'surgeon',
#  'taekwondo athlete',
#  'tailor',
#  'tax collector',
#  'teacher',
#  'telegraphy',
#  'television actor',
#  'television presenter',
#  'tennis player',
#  'terrorist',
#  'textile designer',
#  'theologian',
#  'theoretical biologist',
#  'theoretical physicist',
#  'theoretical physics',
#  'topologist',
#  'toponymist',
#  'trade unionist',
#  'translator',
#  'travel',
#  'ufologist',
#  'university teacher',
#  'vicar',
#  'vice president',
#  'violinist',
#  'volcanologist',
#  'watchmaker',
#  'writer',
#  'zoologist',
#  'École polytechnique fédérale de Lausanne'}

# %% [markdown]
# Apart from having some unusual entries in the list of unique occupations (which we will ignore for the sake of time), it has a broad variety of occupations which shows how flexible Mathematicians are.
# - - - - -

# %% [markdown]
# ## Analysing gender distribution

# %% [markdown]
# Now let's take a look into the difference between the number of male and female mathematicians:

# %%
# Print out the unique entries in the "sex or gender" column
set(df["sex or gender"])
# Out:
# {"['female', 'Italian Wikipedia']",
#  "['female']",
#  "['intersex', 'female']",
#  "['male', 'Integrated Authority File', '9 April 2014', 'data.bnf.fr', '10 October 2015', 'http://data.bnf.fr/ark:/12148/cb119176085']",
#  "['male', 'Swedish Wikipedia', 'Virtual International Authority File', 'Italian Wikipedia']",
#  "['male', 'Virtual International Authority File', 'Integrated Authority File', '9 April 2014', 'data.bnf.fr', '10 October 2015', 'http://data.bnf.fr/ark:/12148/cb118976048']",
#  "['male', 'Virtual International Authority File', 'Italian Wikipedia']",
#  "['male']",
#  nan}

# %% [markdown]
# It seems to produce some weird entries like ['male', 'Swedish Wikipedia', 'Virtual International Authority File', 'Italian Wikipedia'] containing info that should not be in the gender column. This is definitely not the format that we want the gender column to have.
#
# In the following tasks, we are going to modify the dataset to match what we need.

# %% [markdown]
# Looking closely at the unique entries in "sex or gender", we either have <b>male</b>, <b>female</b>, <b>intersex</b> or <b>NaN</b>. Some of the entries have those words with some other unwanted entries, but we know that each entry contains one of those 4 words.  This makes it easy to change every entry in the column so that it is either "male", "female", "intersex" or "not specified".
#
# We use a function called <b>str.contains</b> which checks every string entry in a list on whether it contains a specific word (or generally a combination of characters of interest) and outputs a list with each entry being either a True or False, where True represents the existence of the word in the entry, and False the absence.
#
# Read more about it here: https://pandas.pydata.org/docs/reference/api/pandas.Series.str.contains.html and use it in order to create four new boolean columns in the dataframe: "male", "female", "intersex" and "not specified".

# %%
# Create the three new columns specified above in the dataframe
df['sex or gender'] = df['sex or gender'].fillna('') #This replaces the NaN values with empty values in order to be able to apply str.contains
df['male']=df['sex or gender'].str.contains("'male'")
df['female']=df['sex or gender'].str.contains("'female'")
df['intersex']=df['sex or gender'].str.contains("'intersex'")
df['not specified'] = ~(df['sex or gender'].str.contains("'intersex'")) & ~(df['sex or gender'].str.contains("'female'")) & ~(df['sex or gender'].str.contains("'male'"))

# %%
# Count the number of males
male = df['male'].sum()
male
# Out:
# 7778

# %%
# Count the number of females
female = df['female'].sum()
female
# Out:
# 790

# %%
# Count the number of intersex
intersex = df['intersex'].sum()
intersex
# Out:
# 1

# %%
# Count the number of not specified
unspecified = df['not specified'].sum()
unspecified
# Out:
# 28

# %%
# Calculate the proportions of male and female mathematicians in the dataset
print('The proportions are:')
print('Male =',male*100 /(female + male + intersex + unspecified), '%')
print('Female =', female*100 /(female + male + intersex + unspecified), '%' )
# Out:
# The proportions are:
# Male = 90.47342096080028 %
# Female = 9.189252064673724 %

# %% [markdown]
# Now that is a big difference between the number of male and female Mathematicians. This is a clear indication that the data is biased towards male Mathematicians.
#
# Do you think that this might be a problem when using the data for predictions and drawing conclusions? Have a think about it.
#
# We now create a new column called gender that has one of the following values: male, female, intersex or not specified.

# %%
# This code creates the gender column with the format that we want
gender = []
x = range(df.shape[0])
for i in x:
    if df['sex or gender'].str.contains("'male'")[i] == True:
        gender.append('male')
    elif df['sex or gender'].str.contains("'intersex'")[i] == True: 
        gender.append('intersex')
    elif df['sex or gender'].str.contains("'female'")[i] == True:
        gender.append('female')
    else: 
        gender.append('not specified')

# %%
# Replace the 'sex or gender' column with 'gender'
df['sex or gender'] = gender

# %%
# Preview the 'sex or gender' column
df['sex or gender']
# Out:
# 0         male
# 1       female
# 2         male
# 3         male
# 4         male
#          ...
# 8591      male
# 8592      male
# 8593      male
# 8594      male
# 8595      male
# Name: sex or gender, Length: 8596, dtype: object

# %% [markdown]
# All solved! Now that we formatted the 'sex or gender' column, we can get rid of the boolean columns 'male', 'female', 'intersex' and 'not-specified'

# %%
# Remove the following columns: 'male', 'female', 'intersex' and 'not-specified'
df = df.drop(columns = ['male', 'female', 'intersex', 'not specified'])
df
# Out:
#               mathematicians  \
# 0     Roger Joseph Boscovich
# 1              Emma Previato
# 2              Feodor Deahna
# 3              Denis Henrion
# 4             Henri Delannoy
# ...                      ...
# 8591  Hugh Hamilton (bishop)
# 8592            Boáz Klartag
# 8593         Alain M. Robert
# 8594      Paul C. Rosenbloom
# 8595         Edward O. Thorp
#
#                                              occupation  \
# 0     ['physicist', 'astronomer', 'mathematician', '...
# 1                                     ['mathematician']
# 2                                     ['mathematician']
# 3                        ['publisher', 'mathematician']
# 4     ['mathematician', 'historian', 'military perso...
# ...                                                 ...
# 8591                                         ['priest']
# 8592            ['mathematician', 'university teacher']
# 8593                                  ['mathematician']
# 8594                                  ['mathematician']
# 8595  ['mathematician', 'writer', 'university teacher']
#
#                      country of citizenship                 place of birth  \
# 0                    ['Republic of Ragusa']  Dubrovnik, Republic of Ragusa
# 1     ['United States of America', 'Italy']                 Badia Polesine
# 2                                       NaN                            NaN
# 3                                ['France']                            NaN
# 4                                ['France']            Bourbonne-les-Bains
# ...                                     ...                            ...
# 8591                                    NaN                  County Dublin
# 8592                             ['Israel']                            NaN
# 8593                        ['Switzerland']                            NaN
# 8594           ['United States of America']                     Portsmouth
# 8595           ['United States of America']                        Chicago
#
#          date of death                                    educated at  \
# 0     13 February 1787            ['Pontifical Gregorian University']
# 1                  NaN  ['Harvard University', 'University of Padua']
# 2                 1844                                            NaN
# 3                 1640                                            NaN
# 4      5 February 1915                        ['École Polytechnique']
# ...                ...                                            ...
# 8591   1 December 1805                     ['Trinity College Dublin']
# 8592               NaN                        ['Tel Aviv University']
# 8593               NaN                                            NaN
# 8594          May 2005                                            NaN
# 8595               NaN      ['University of California, Los Angeles']
#
#                                                employer  \
# 0                   ['Pontifical Gregorian University']
# 1          ['Boston University', 'University of Padua']
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8591                                                NaN
# 8592                                                NaN
# 8593                                                NaN
# 8594                                                NaN
# 8595  ['New Mexico State University', 'University of...
#
#                     place of death  \
# 0     ['Milan', 'Habsburg Empire']
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                       ['Guéret']
# ...                            ...
# 8591                  ['Kilkenny']
# 8592                           NaN
# 8593                           NaN
# 8594                           NaN
# 8595                           NaN
#
#                                               member of  \
# 0     ['Royal Society', 'Russian Academy of Sciences...
# 1                     ['American Mathematical Society']
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8591                                  ['Royal Society']
# 8592                                                NaN
# 8593                                                NaN
# 8594                                                NaN
# 8595                                                NaN
#
#                                              employer.1  ... instance of  \
# 0                   ['Pontifical Gregorian University']  ...   ['human']
# 1          ['Boston University', 'University of Padua']  ...   ['human']
# 2                                                   NaN  ...   ['human']
# 3                                                   NaN  ...   ['human']
# 4                                                   NaN  ...   ['human']
# ...                                                 ...  ...         ...
# 8591                                                NaN  ...   ['human']
# 8592                                                NaN  ...   ['human']
# 8593                                                NaN  ...   ['human']
# 8594                                                NaN  ...   ['human']
# 8595  ['New Mexico State University', 'University of...  ...   ['human']
#
#      sex or gender approx. date of birth day of birth month of birth  \
# 0             male                 False         18.0            May
# 1           female                 False          NaN            NaN
# 2             male                 False          NaN            NaN
# 3             male                  True          NaN            NaN
# 4             male                 False         28.0      September
# ...            ...                   ...          ...            ...
# 8591          male                 False         26.0          March
# 8592          male                 False         25.0          April
# 8593          male                 False         15.0        October
# 8594          male                 False         31.0          March
# 8595          male                 False         14.0         August
#
#      year of birth approx. date of death day of death month of death  \
# 0             1711                 False         13.0       February
# 1             1952                 False          NaN            NaN
# 2             1815                 False          NaN            NaN
# 3             1500                 False          NaN            NaN
# 4             1833                 False          5.0       February
# ...            ...                   ...          ...            ...
# 8591          1729                 False          1.0       December
# 8592          1978                 False          NaN            NaN
# 8593          1941                 False          NaN            NaN
# 8594          1920                 False          NaN            May
# 8595          1932                 False          NaN            NaN
#
#      year of death
# 0             1787
# 1              NaN
# 2             1844
# 3             1640
# 4             1915
# ...            ...
# 8591          1805
# 8592           NaN
# 8593           NaN
# 8594          2005
# 8595           NaN
#
# [8596 rows x 29 columns]

# %% [markdown]
# ## Analysing the dataset

# %%
# Are there any rows that do not have any missing values? (Output True or False)
(df.isna().sum(axis=1) == 0).any()
# Out:
# False

# %%
# Output the rows that have at least 10 missing values
df.loc[df.isna().sum(axis = 1) >= 10]
# Out:
#               mathematicians  \
# 1              Emma Previato
# 2              Feodor Deahna
# 3              Denis Henrion
# 4             Henri Delannoy
# 5                John Hymers
# ...                      ...
# 8591  Hugh Hamilton (bishop)
# 8592            Boáz Klartag
# 8593         Alain M. Robert
# 8594      Paul C. Rosenbloom
# 8595         Edward O. Thorp
#
#                                              occupation  \
# 1                                     ['mathematician']
# 2                                     ['mathematician']
# 3                        ['publisher', 'mathematician']
# 4     ['mathematician', 'historian', 'military perso...
# 5                                     ['mathematician']
# ...                                                 ...
# 8591                                         ['priest']
# 8592            ['mathematician', 'university teacher']
# 8593                                  ['mathematician']
# 8594                                  ['mathematician']
# 8595  ['mathematician', 'writer', 'university teacher']
#
#                      country of citizenship       place of birth  \
# 1     ['United States of America', 'Italy']       Badia Polesine
# 2                                       NaN                  NaN
# 3                                ['France']                  NaN
# 4                                ['France']  Bourbonne-les-Bains
# 5                                       NaN              Ormesby
# ...                                     ...                  ...
# 8591                                    NaN        County Dublin
# 8592                             ['Israel']                  NaN
# 8593                        ['Switzerland']                  NaN
# 8594           ['United States of America']           Portsmouth
# 8595           ['United States of America']              Chicago
#
#         date of death                                    educated at  \
# 1                 NaN  ['Harvard University', 'University of Padua']
# 2                1844                                            NaN
# 3                1640                                            NaN
# 4     5 February 1915                        ['École Polytechnique']
# 5        7 April 1887                          ["St John's College"]
# ...               ...                                            ...
# 8591  1 December 1805                     ['Trinity College Dublin']
# 8592              NaN                        ['Tel Aviv University']
# 8593              NaN                                            NaN
# 8594         May 2005                                            NaN
# 8595              NaN      ['University of California, Los Angeles']
#
#                                                employer     place of death  \
# 1          ['Boston University', 'University of Padua']                NaN
# 2                                                   NaN                NaN
# 3                                                   NaN                NaN
# 4                                                   NaN         ['Guéret']
# 5                                                   NaN  ['Brandesburton']
# ...                                                 ...                ...
# 8591                                                NaN       ['Kilkenny']
# 8592                                                NaN                NaN
# 8593                                                NaN                NaN
# 8594                                                NaN                NaN
# 8595  ['New Mexico State University', 'University of...                NaN
#
#                               member of  \
# 1     ['American Mathematical Society']
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                     ['Royal Society']
# ...                                 ...
# 8591                  ['Royal Society']
# 8592                                NaN
# 8593                                NaN
# 8594                                NaN
# 8595                                NaN
#
#                                              employer.1  ... instance of  \
# 1          ['Boston University', 'University of Padua']  ...   ['human']
# 2                                                   NaN  ...   ['human']
# 3                                                   NaN  ...   ['human']
# 4                                                   NaN  ...   ['human']
# 5                                                   NaN  ...   ['human']
# ...                                                 ...  ...         ...
# 8591                                                NaN  ...   ['human']
# 8592                                                NaN  ...   ['human']
# 8593                                                NaN  ...   ['human']
# 8594                                                NaN  ...   ['human']
# 8595  ['New Mexico State University', 'University of...  ...   ['human']
#
#      sex or gender approx. date of birth day of birth month of birth  \
# 1           female                 False          NaN            NaN
# 2             male                 False          NaN            NaN
# 3             male                  True          NaN            NaN
# 4             male                 False         28.0      September
# 5             male                 False         20.0           July
# ...            ...                   ...          ...            ...
# 8591          male                 False         26.0          March
# 8592          male                 False         25.0          April
# 8593          male                 False         15.0        October
# 8594          male                 False         31.0          March
# 8595          male                 False         14.0         August
#
#      year of birth approx. date of death day of death month of death  \
# 1             1952                 False          NaN            NaN
# 2             1815                 False          NaN            NaN
# 3             1500                 False          NaN            NaN
# 4             1833                 False          5.0       February
# 5             1803                 False          7.0          April
# ...            ...                   ...          ...            ...
# 8591          1729                 False          1.0       December
# 8592          1978                 False          NaN            NaN
# 8593          1941                 False          NaN            NaN
# 8594          1920                 False          NaN            May
# 8595          1932                 False          NaN            NaN
#
#      year of death
# 1              NaN
# 2             1844
# 3             1640
# 4             1915
# 5             1887
# ...            ...
# 8591          1805
# 8592           NaN
# 8593           NaN
# 8594          2005
# 8595           NaN
#
# [6827 rows x 29 columns]

# %%
# Output the rows of the mathematicians that have the year of birth filled in, name the list of rows x
x = df.loc[df['year of birth'].isna() == False]
x
# Out:
#               mathematicians  \
# 0     Roger Joseph Boscovich
# 1              Emma Previato
# 2              Feodor Deahna
# 3              Denis Henrion
# 4             Henri Delannoy
# ...                      ...
# 8591  Hugh Hamilton (bishop)
# 8592            Boáz Klartag
# 8593         Alain M. Robert
# 8594      Paul C. Rosenbloom
# 8595         Edward O. Thorp
#
#                                              occupation  \
# 0     ['physicist', 'astronomer', 'mathematician', '...
# 1                                     ['mathematician']
# 2                                     ['mathematician']
# 3                        ['publisher', 'mathematician']
# 4     ['mathematician', 'historian', 'military perso...
# ...                                                 ...
# 8591                                         ['priest']
# 8592            ['mathematician', 'university teacher']
# 8593                                  ['mathematician']
# 8594                                  ['mathematician']
# 8595  ['mathematician', 'writer', 'university teacher']
#
#                      country of citizenship                 place of birth  \
# 0                    ['Republic of Ragusa']  Dubrovnik, Republic of Ragusa
# 1     ['United States of America', 'Italy']                 Badia Polesine
# 2                                       NaN                            NaN
# 3                                ['France']                            NaN
# 4                                ['France']            Bourbonne-les-Bains
# ...                                     ...                            ...
# 8591                                    NaN                  County Dublin
# 8592                             ['Israel']                            NaN
# 8593                        ['Switzerland']                            NaN
# 8594           ['United States of America']                     Portsmouth
# 8595           ['United States of America']                        Chicago
#
#          date of death                                    educated at  \
# 0     13 February 1787            ['Pontifical Gregorian University']
# 1                  NaN  ['Harvard University', 'University of Padua']
# 2                 1844                                            NaN
# 3                 1640                                            NaN
# 4      5 February 1915                        ['École Polytechnique']
# ...                ...                                            ...
# 8591   1 December 1805                     ['Trinity College Dublin']
# 8592               NaN                        ['Tel Aviv University']
# 8593               NaN                                            NaN
# 8594          May 2005                                            NaN
# 8595               NaN      ['University of California, Los Angeles']
#
#                                                employer  \
# 0                   ['Pontifical Gregorian University']
# 1          ['Boston University', 'University of Padua']
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8591                                                NaN
# 8592                                                NaN
# 8593                                                NaN
# 8594                                                NaN
# 8595  ['New Mexico State University', 'University of...
#
#                     place of death  \
# 0     ['Milan', 'Habsburg Empire']
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                       ['Guéret']
# ...                            ...
# 8591                  ['Kilkenny']
# 8592                           NaN
# 8593                           NaN
# 8594                           NaN
# 8595                           NaN
#
#                                               member of  \
# 0     ['Royal Society', 'Russian Academy of Sciences...
# 1                     ['American Mathematical Society']
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8591                                  ['Royal Society']
# 8592                                                NaN
# 8593                                                NaN
# 8594                                                NaN
# 8595                                                NaN
#
#                                              employer.1  ... instance of  \
# 0                   ['Pontifical Gregorian University']  ...   ['human']
# 1          ['Boston University', 'University of Padua']  ...   ['human']
# 2                                                   NaN  ...   ['human']
# 3                                                   NaN  ...   ['human']
# 4                                                   NaN  ...   ['human']
# ...                                                 ...  ...         ...
# 8591                                                NaN  ...   ['human']
# 8592                                                NaN  ...   ['human']
# 8593                                                NaN  ...   ['human']
# 8594                                                NaN  ...   ['human']
# 8595  ['New Mexico State University', 'University of...  ...   ['human']
#
#      sex or gender approx. date of birth day of birth month of birth  \
# 0             male                 False         18.0            May
# 1           female                 False          NaN            NaN
# 2             male                 False          NaN            NaN
# 3             male                  True          NaN            NaN
# 4             male                 False         28.0      September
# ...            ...                   ...          ...            ...
# 8591          male                 False         26.0          March
# 8592          male                 False         25.0          April
# 8593          male                 False         15.0        October
# 8594          male                 False         31.0          March
# 8595          male                 False         14.0         August
#
#      year of birth approx. date of death day of death month of death  \
# 0             1711                 False         13.0       February
# 1             1952                 False          NaN            NaN
# 2             1815                 False          NaN            NaN
# 3             1500                 False          NaN            NaN
# 4             1833                 False          5.0       February
# ...            ...                   ...          ...            ...
# 8591          1729                 False          1.0       December
# 8592          1978                 False          NaN            NaN
# 8593          1941                 False          NaN            NaN
# 8594          1920                 False          NaN            May
# 8595          1932                 False          NaN            NaN
#
#      year of death
# 0             1787
# 1              NaN
# 2             1844
# 3             1640
# 4             1915
# ...            ...
# 8591          1805
# 8592           NaN
# 8593           NaN
# 8594          2005
# 8595           NaN
#
# [7625 rows x 29 columns]

# %% [markdown]
# The following tasks are going to require the knowledge of a function called <b>str.contains</b> which is mentioned and explained in the section named <b>Analysing gender distribution</b> in this notebook.

# %%
# Check the datatype of the 'year of birth' column
x['year of birth'].dtype
# Out:
# dtype('O')

# %% [markdown]
# We would like to have the data type of the entries of the 'year of birth' column to be numeric in order to be able to perform mathematical operations that will be needed in the following tasks.
#
# In the next task, convert the data type of the column 'year of birth' to numeric. Do you run into a problem? Inspect the column entries to find out what is causing it and fix it.
#
# Note: You can either edit the entries that are causing the problems, or remove them entirely.

# %%
# Convert the datatype of the column 'year of birth' to numeric
x = x.drop(x.loc[x['year of birth'].str.contains('s')].index)
x['year of birth'] = pd.to_numeric(x['year of birth'])

# %%
# Output the row of the oldest mathematician in x
x.loc[x['year of birth'] == x['year of birth'].min()]
# Out:
#      mathematicians                                occupation  \
# 8087          Ahmes  ['scribe', 'mathematician', 'Q19163412']
#
#      country of citizenship place of birth date of death educated at employer  \
# 8087              ['Egypt']          Egypt      1620 BCE         NaN      NaN
#
#      place of death member of employer.1  ... instance of sex or gender  \
# 8087            NaN       NaN        NaN  ...   ['human']          male
#
#      approx. date of birth day of birth month of birth year of birth  \
# 8087                 False          NaN            NaN         -1680
#
#      approx. date of death day of death month of death year of death
# 8087                 False          NaN            NaN         -1620
#
# [1 rows x 29 columns]

# %%
# Output the row of the most recently born mathematician in x
x.loc[x['year of birth'] == x['year of birth'].max()]
# Out:
#      mathematicians         occupation country of citizenship place of birth  \
# 5704    Yasha Asley  ['mathematician']                    NaN            NaN
#
#      date of death educated at employer place of death member of employer.1  \
# 5704           NaN         NaN      NaN            NaN       NaN        NaN
#
#       ... instance of sex or gender approx. date of birth day of birth  \
# 5704  ...   ['human']          male                 False          NaN
#
#      month of birth year of birth approx. date of death day of death  \
# 5704            NaN          2003                 False          NaN
#
#      month of death year of death
# 5704            NaN           NaN
#
# [1 rows x 29 columns]

# %%
# Output the range of the year of birth column
x['year of birth'].max() - x['year of birth'].min()
# Out:
# 3683

# %%
# Output the rows of the mathematicians that have studied at the University of Cambridge
df.loc[df['educated at'].str.contains('Cambridge') == True]
# Out:
#                     mathematicians  \
# 49    Thomas John I'Anson Bromwich
# 153                   Isaac Barrow
# 284              Edward H. Simpson
# 567                 Kevin Costello
# 676             Derek Frank Lawden
# ...                            ...
# 8197                 Freeman Dyson
# 8200                  Tamás Hausel
# 8233                Seymour Papert
# 8420                Sarah Woodhead
# 8524           Ebenezer Cunningham
#
#                                              occupation  \
# 49                       ['mathematician', 'physicist']
# 153   ['theologian', 'mathematician', 'historian of ...
# 284                   ['mathematician', 'statistician']
# 567             ['mathematician', 'university teacher']
# 676                                   ['mathematician']
# ...                                                 ...
# 8197  ['mathematician', 'theoretical physicist', 'nu...
# 8200                                  ['mathematician']
# 8233  ['mathematician', 'computer scientist', 'educa...
# 8420                        ['head teacher', 'teacher']
# 8524                     ['mathematician', 'physicist']
#
#                               country of citizenship  \
# 49                                ['United Kingdom']
# 153                           ['Kingdom of England']
# 284                               ['United Kingdom']
# 567                                              NaN
# 676                                  ['New Zealand']
# ...                                              ...
# 8197  ['United Kingdom', 'United States of America']
# 8200                                     ['Hungary']
# 8233    ['South Africa', 'United States of America']
# 8420                              ['United Kingdom']
# 8524                              ['United Kingdom']
#
#                  place of birth     date of death  \
# 49                Wolverhampton    26 August 1929
# 153                      London        4 May 1677
# 284                         NaN               NaN
# 567                        Cork               NaN
# 676                  Birmingham  15 February 2008
# ...                         ...               ...
# 8197                 Crowthorne               NaN
# 8200                    Hungary               NaN
# 8233                   Pretoria      31 July 2016
# 8420                        NaN              1912
# 8524  London Borough of Hackney  12 February 1977
#
#                                             educated at  \
# 49     ['University of Cambridge', "St John's College"]
# 153   ['University of Cambridge', 'Trinity College',...
# 284                         ['University of Cambridge']
# 567                         ['University of Cambridge']
# 676                         ['University of Cambridge']
# ...                                                 ...
# 8197  ['University of Cambridge', 'Cornell Universit...
# 8200  ['Eötvös Loránd University', 'University of Ca...
# 8233  ['University of the Witwatersrand', '1952', 'd...
# 8420                        ['University of Cambridge']
# 8524   ['University of Cambridge', "St John's College"]
#
#                                                employer   place of death  \
# 49                                                  NaN  ['Northampton']
# 153                                 ['Gresham College']       ['London']
# 284                                                 NaN              NaN
# 567                                                 NaN              NaN
# 676                        ['University of Canterbury']      ['Warwick']
# ...                                                 ...              ...
# 8197                                                NaN              NaN
# 8200  ['University of Oxford', 'Institute for Advanc...              NaN
# 8233  ['Massachusetts Institute of Technology', '1963']    ['Blue Hill']
# 8420                                  ['Bolton School']              NaN
# 8524                                                NaN              NaN
#
#                                               member of  \
# 49                                    ['Royal Society']
# 153                                   ['Royal Society']
# 284                                                 NaN
# 567                                                 NaN
# 676                                                 NaN
# ...                                                 ...
# 8197  ['Royal Society', 'French Academy of Sciences'...
# 8200                                                NaN
# 8233                                                NaN
# 8420                                                NaN
# 8524                                                NaN
#
#                                              employer.1  ... instance of  \
# 49                                                  NaN  ...   ['human']
# 153                                 ['Gresham College']  ...   ['human']
# 284                                                 NaN  ...   ['human']
# 567                                                 NaN  ...   ['human']
# 676                        ['University of Canterbury']  ...   ['human']
# ...                                                 ...  ...         ...
# 8197                                                NaN  ...   ['human']
# 8200  ['University of Oxford', 'Institute for Advanc...  ...   ['human']
# 8233  ['Massachusetts Institute of Technology', '1963']  ...   ['human']
# 8420                                  ['Bolton School']  ...   ['human']
# 8524                                                NaN  ...   ['human']
#
#      sex or gender approx. date of birth day of birth month of birth  \
# 49            male                 False          8.0       February
# 153           male                 False          NaN        October
# 284           male                 False         10.0       December
# 567           male                 False          NaN            NaN
# 676           male                 False         15.0      September
# ...            ...                   ...          ...            ...
# 8197          male                 False         15.0       December
# 8200          male                 False          NaN            NaN
# 8233          male                 False         29.0       February
# 8420        female                 False          NaN            NaN
# 8524          male                 False          7.0            May
#
#      year of birth approx. date of death day of death month of death  \
# 49            1875                 False         26.0         August
# 153           1630                 False          4.0            May
# 284           1922                 False          NaN            NaN
# 567           1977                 False          NaN            NaN
# 676           1919                 False         15.0       February
# ...            ...                   ...          ...            ...
# 8197          1923                 False          NaN            NaN
# 8200          1972                 False          NaN            NaN
# 8233          1928                 False         31.0           July
# 8420          1851                 False          NaN            NaN
# 8524          1881                 False         12.0       February
#
#      year of death
# 49            1929
# 153           1677
# 284            NaN
# 567            NaN
# 676           2008
# ...            ...
# 8197           NaN
# 8200           NaN
# 8233          2016
# 8420          1912
# 8524          1977
#
# [104 rows x 29 columns]

# %%
# How many mathematicians were interested in any of the fields of Analysis?
df.loc[df['field of work'].str.contains('analysis') == True].s

# %% [markdown]
# ## Extra task

# %% [markdown]
# Here is a link for you to check out that shows the investigations that the owner of this dataset performed: https://www.kaggle.com/joephilleo/investigating-the-mathematicians-of-wikipedia
